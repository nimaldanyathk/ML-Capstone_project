# %% [markdown]
# # NASA Kepler Objects of Interest - Classification
#
# This notebook prepares the classification track using the NASA Kepler Objects of Interest dataset.
#
# The preprocessing is kept close to the course PDF requirements:
#
# - load and audit the dataset
# - check missing values, duplicates, and outliers
# - create at least one engineered feature
# - split with stratification
# - fit imputers/scalers only on training data
# - evaluate classifiers with the required classification metrics

# %% [markdown]
# ## 1. Problem Statement
#
# The task is to predict the official KOI disposition class for a Kepler Object of Interest using tabular measurements from the dataset.

# %% [markdown]
# ## 2. Dataset Description
#
# Dataset: NASA Kepler Objects of Interest (KOI)
#
# Official source: https://data.nasa.gov/dataset/kepler-objects-of-interest-koi
#
# CSV source used in this notebook: https://exoplanetarchive.ipac.caltech.edu/TAP/sync?query=select+*+from+cumulative&format=csv

# %% [markdown]
# ## 3. Imports and Reproducibility

# %%
from pathlib import Path
import io
import warnings

import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns

from sklearn.compose import ColumnTransformer
from sklearn.impute import SimpleImputer
from sklearn.metrics import (
    ConfusionMatrixDisplay,
    accuracy_score,
    classification_report,
    confusion_matrix,
    f1_score,
    precision_score,
    recall_score,
    roc_auc_score,
    roc_curve,
)
from sklearn.model_selection import GridSearchCV, train_test_split
from sklearn.naive_bayes import GaussianNB
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import StandardScaler, label_binarize
from sklearn.tree import DecisionTreeClassifier, plot_tree

warnings.filterwarnings("ignore", category=FutureWarning)

RANDOM_STATE = 42
TEST_SIZE = 0.20

sns.set_theme(style="whitegrid", palette="colorblind")
pd.set_option("display.max_columns", 100)

# %% [markdown]
# ## 4. Data Loading

# %%
DATA_URL = "https://exoplanetarchive.ipac.caltech.edu/TAP/sync?query=select+*+from+cumulative&format=csv"

project_root = Path.cwd().resolve()
if project_root.name == "notebooks":
    project_root = project_root.parent

DATA_PATH = project_root / "data" / "kepler_koi.csv"

if DATA_PATH.exists():
    print(f"Loading local dataset: {DATA_PATH}")
    df = pd.read_csv(DATA_PATH)
else:
    print("Local dataset not found. Downloading from the Exoplanet Archive...")
    df = pd.read_csv(DATA_URL)
    DATA_PATH.parent.mkdir(parents=True, exist_ok=True)
    df.to_csv(DATA_PATH, index=False)
    print(f"Saved dataset to: {DATA_PATH}")
# Out:
# Loading local dataset: /Users/nimaldanyathk/git/ML-Capstone_project/data/kepler_koi.csv

# %% [markdown]
# ## 5. Dataset Audit

# %%
display(df.head())
print(f"Shape: {df.shape[0]:,} rows x {df.shape[1]:,} columns")
# Out:
#       kepid kepoi_name   kepler_name         ra  ra_err        ra_str  \
# 0  10797460  K00752.01  Kepler-227 b  291.93423     0.0  19h27m44.22s
# 1  10797460  K00752.02  Kepler-227 c  291.93423     0.0  19h27m44.22s
# 2  10811496  K00753.01           NaN  297.00482     0.0  19h48m01.16s
# 3  10848459  K00754.01           NaN  285.53461     0.0  19h02m08.31s
# 4  10854555  K00755.01  Kepler-664 b  288.75488     0.0  19h15m01.17s
#
#          dec  dec_err       dec_str  koi_gmag  koi_gmag_err  koi_rmag  \
# 0  48.141651      0.0  +48d08m29.9s    15.890           NaN    15.270
# 1  48.141651      0.0  +48d08m29.9s    15.890           NaN    15.270
# 2  48.134129      0.0  +48d08m02.9s    15.943           NaN    15.390
# 3  48.285210      0.0  +48d17m06.8s    16.100           NaN    15.554
# 4  48.226200      0.0  +48d13m34.3s    16.015           NaN    15.468
#
#    koi_rmag_err  koi_imag  koi_imag_err  koi_zmag  koi_zmag_err  koi_jmag  \
# ...

# %%
print("Columns:")
print(df.columns.tolist())
# Out:
# Columns:
# ...

# %%
info_buffer = io.StringIO()
df.info(buf=info_buffer)
print(info_buffer.getvalue())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9564 entries, 0 to 9563
# Columns: 153 entries, kepid to koi_score
# dtypes: float64(127), int64(6), object(20)
# memory usage: 11.2+ MB

# %%
audit_table = pd.DataFrame({
    "dtype": df.dtypes.astype(str),
    "missing_count": df.isna().sum(),
    "missing_percent": df.isna().mean().mul(100).round(2),
    "unique_values": df.nunique(dropna=True),
})

display(audit_table.sort_values("missing_percent", ascending=False))
# Out:
#                   dtype  missing_count  missing_percent  unique_values
# koi_sma_err2    float64           9564            100.0              0
# koi_incl_err2   float64           9564            100.0              0
# koi_kepmag_err  float64           9564            100.0              0
# koi_incl_err1   float64           9564            100.0              0
# koi_model_dof   float64           9564            100.0              0
# ...                 ...            ...              ...            ...
# ra_str           object              0              0.0           8103
# dec             float64              0              0.0           8195
# dec_err         float64              0              0.0              1
# dec_str          object              0              0.0           8144
# kepid             int64              0              0.0           8214
#
# [153 rows x 4 columns]

# %% [markdown]
# ## 6. Target Definition

# %%
target_column = "koi_disposition"

if target_column not in df.columns:
    raise KeyError(f"Target column not found: {target_column}")

class_counts = df[target_column].value_counts()
class_percentages = df[target_column].value_counts(normalize=True).mul(100).round(2)
target_distribution = pd.DataFrame({
    "count": class_counts,
    "percentage": class_percentages,
})

print(f"Selected classification target: {target_column}")
print(f"Target classes: {sorted(df[target_column].dropna().unique().tolist())}")
display(target_distribution)
# Out:
# Selected classification target: koi_disposition
# Target classes: ['CANDIDATE', 'CONFIRMED', 'FALSE POSITIVE']
#                  count  percentage
# koi_disposition
# FALSE POSITIVE    4839       50.60
# CONFIRMED         2748       28.73
# CANDIDATE         1977       20.67

# %% [markdown]
# `koi_disposition` is used as the target because it directly stores the KOI disposition classes in the dataset.

# %%
plt.figure(figsize=(8, 5))
sns.countplot(data=df, x=target_column, order=class_counts.index)
plt.title("Target Distribution")
plt.xlabel("KOI disposition")
plt.ylabel("Count")
plt.xticks(rotation=20)
plt.tight_layout()
plt.show()

# %% [markdown]
# **Observation:** The target is moderately imbalanced. `FALSE POSITIVE` is the majority class with 4,839 records (50.60%), followed by `CONFIRMED` with 2,748 (28.73%) and `CANDIDATE` with 1,977 (20.67%). A stratified train/test split is therefore important so that each subset preserves these proportions, and weighted metrics should be reported alongside accuracy.

# %% [markdown]
# ## 7. Exploratory Data Analysis

# %%
eda_features = [
    "koi_period",
    "koi_duration",
    "koi_depth",
    "koi_prad",
    "koi_teq",
    "koi_insol",
    "koi_model_snr",
    "koi_steff",
    "koi_slogg",
    "koi_srad",
    "koi_smass",
]

eda_features = [column for column in eda_features if column in df.columns]
display(df[eda_features].describe().T)
# Out:
#                 count          mean            std          min          25%  \
# koi_period     9564.0     75.671358    1334.744046     0.241843     2.733684
# koi_duration   9564.0      5.621606       6.471554     0.052000     2.437750
# koi_depth      9201.0  23791.343984   82242.684708     0.000000   159.900000
# koi_prad       9201.0    102.891778    3077.639126     0.080000     1.400000
# koi_teq        9201.0   1085.385828     856.351161    25.000000   539.000000
# koi_insol      9243.0   7745.737023  159204.665200     0.000000    20.150000
# koi_model_snr  9201.0    259.895001     795.806615     0.000000    12.000000
# koi_steff      9201.0   5706.823280     796.857947  2661.000000  5310.000000
# koi_slogg      9201.0      4.310157       0.432606     0.047000     4.218000
# koi_srad       9201.0      1.728712       6.127185     0.109000     0.829000
# koi_smass      9201.0      1.023706       0.349447     0.000000     0.845000
#
# ...

# %%
plot_features = eda_features
n_columns = 3
n_rows = int(np.ceil(len(plot_features) / n_columns))
fig, axes = plt.subplots(n_rows, n_columns, figsize=(15, 3.5 * n_rows), squeeze=False)
axes = axes.ravel()

for axis, column in zip(axes, plot_features):
    sns.histplot(df[column], kde=True, ax=axis)
    axis.set_title(f"Distribution of {column}")
    axis.set_xlabel(column)
    axis.set_ylabel("Count")

for axis in axes[len(plot_features):]:
    axis.set_visible(False)

plt.tight_layout()
plt.show()

# %% [markdown]
# **Observation:** The distribution grid covers all 11 selected EDA features. Most transit and planetary measurements—especially `koi_period`, `koi_depth`, `koi_prad`, `koi_insol`, and `koi_model_snr`—are strongly right-skewed, with a small number of very large values pulling their means well above their medians. The stellar variables `koi_steff`, `koi_slogg`, and `koi_smass` are more concentrated, although `koi_srad` also has a long right tail. These shapes support robust missing-value imputation and scaling inside the modelling pipeline rather than assuming normally distributed predictors or deleting every extreme observation.

# %%
correlation_features = eda_features

plt.figure(figsize=(10, 7))
sns.heatmap(df[correlation_features].corr(numeric_only=True), cmap="coolwarm", center=0)
plt.title("Correlation Heatmap")
plt.tight_layout()
plt.show()

# %% [markdown]
# **Observation:** The heatmap shows meaningful relationships among several stellar variables: surface gravity (`koi_slogg`) is negatively correlated with stellar mass (`koi_smass`, about -0.69) and stellar radius (`koi_srad`, about -0.64), while effective temperature (`koi_steff`) is positively correlated with stellar mass (about 0.59). Transit depth and model signal-to-noise are also moderately positively correlated (about 0.58). No pair is perfectly correlated, but these relationships indicate some redundancy and interactions that a decision tree can exploit.

# %%
scatter_features = [column for column in ["koi_model_snr", "koi_prad"] if column in df.columns]

for column in scatter_features:
    plt.figure(figsize=(8, 5))
    sns.stripplot(
        data=df,
        x=target_column,
        y=column,
        order=class_counts.index,
        jitter=0.25,
        alpha=0.35,
        size=2,
    )
    plt.title(f"{column} by Target Class")
    plt.xlabel("KOI disposition")
    plt.ylabel(column)
    plt.xticks(rotation=20)
    plt.tight_layout()
    plt.show()

# %% [markdown]
# **Observation:** Both strip plots show heavy overlap between classes, so neither feature separates the target on its own. Even so, `FALSE POSITIVE` objects tend to have larger values: their median `koi_model_snr` is about 34.25 versus 28.60 for `CONFIRMED` and 11.00 for `CANDIDATE`, while their median `koi_prad` is about 8.97 versus 2.16 and 1.74. The wide within-class spread and extreme upper tails suggest that these variables are useful signals when combined with other predictors rather than reliable standalone decision rules.

# %% [markdown]
# ## 8. Data Cleaning

# %%
working_df = df.copy()

duplicate_count = working_df.duplicated().sum()
print(f"Number of duplicate rows: {duplicate_count:,}")

if duplicate_count > 0:
    working_df = working_df.drop_duplicates().copy()
    print(f"Removed {duplicate_count:,} exact duplicate rows.")
else:
    print("No exact duplicate rows found.")
# Out:
# Number of duplicate rows: 0
# No exact duplicate rows found.

# %%
missing_summary = (
    working_df.isna()
    .sum()
    .to_frame("missing_count")
    .assign(missing_percent=lambda x: x["missing_count"].div(len(working_df)).mul(100).round(2))
    .query("missing_count > 0")
    .sort_values("missing_percent", ascending=False)
)

display(missing_summary)
# Out:
#                   missing_count  missing_percent
# koi_incl_err1              9564           100.00
# koi_ingress_err2           9564           100.00
# koi_eccen_err1             9564           100.00
# koi_eccen_err2             9564           100.00
# koi_longp                  9564           100.00
# ...                         ...              ...
# koi_kmag                     25             0.26
# koi_jmag                     25             0.26
# koi_hmag                     25             0.26
# koi_rmag                      9             0.09
# koi_kepmag                    1             0.01
#
# [128 rows x 2 columns]

# %%
outlier_rows = []
for column in eda_features:
    values = working_df[column].dropna()
    q1 = values.quantile(0.25)
    q3 = values.quantile(0.75)
    iqr = q3 - q1
    lower = q1 - 1.5 * iqr
    upper = q3 + 1.5 * iqr
    outlier_count = ((values < lower) | (values > upper)).sum()
    outlier_rows.append({
        "feature": column,
        "potential_outliers": int(outlier_count),
        "outlier_percent": round(outlier_count / len(values) * 100, 2),
    })

outlier_summary = pd.DataFrame(outlier_rows)
display(outlier_summary)
# Out:
#           feature  potential_outliers  outlier_percent
# 0      koi_period                1567            16.38
# 1    koi_duration                 869             9.09
# 2       koi_depth                1798            19.54
# 3        koi_prad                1469            15.97
# 4         koi_teq                 411             4.47
# 5       koi_insol                1438            15.56
# 6   koi_model_snr                1600            17.39
# 7       koi_steff                 552             6.00
# 8       koi_slogg                 663             7.21
# 9        koi_srad                 985            10.71
# 10      koi_smass                 740             8.04

# %% [markdown]
# Missing values are handled later by imputers fitted on training data only. Potential outliers are checked, but not automatically deleted, because extreme astronomical measurements can still be valid observations.

# %% [markdown]
# ## 9. Feature Engineering

# %%
if {"koi_depth", "koi_duration"}.issubset(working_df.columns):
    working_df["transit_depth_per_hour"] = (
        working_df["koi_depth"] / working_df["koi_duration"].replace(0, np.nan)
    )
    engineered_features = ["transit_depth_per_hour"]
else:
    engineered_features = []

print("Engineered features:", engineered_features)
if engineered_features:
    display(working_df[engineered_features].describe().T)
# Out:
# Engineered features: ['transit_depth_per_hour']
#                          count         mean           std  min        25%  \
# transit_depth_per_hour  9201.0  4818.271031  17645.246313  0.0  38.435766
#
#                                50%         75%            max
# transit_depth_per_hour  112.014712  444.746295  416155.623346

# %% [markdown]
# `transit_depth_per_hour` is calculated as `koi_depth / koi_duration`. It combines the strength and duration of a transit into a rate-like measure: deep, short events produce larger values than shallow or long events. Because transit shape can help distinguish planet-like signals from eclipsing binaries and other false positives, this interaction may expose class information that depth and duration do not express separately. Its strong right skew and missing values are handled later by the same training-only imputation and scaling pipeline used for the original numeric features.

# %% [markdown]
# ## 10. Feature and Target Split

# %%
rows_before = len(working_df)
modeling_df = working_df.dropna(subset=[target_column]).copy()
print(f"Rows removed because target is missing: {rows_before - len(modeling_df):,}")

columns_not_used = {
    target_column: "target column",
    "kepid": "identifier column",
    "koi_pdisposition": "another disposition label",
    "koi_score": "disposition score related to the target",
    "koi_fpflag_nt": "false-positive flag related to target decision",
    "koi_fpflag_ss": "false-positive flag related to target decision",
    "koi_fpflag_co": "false-positive flag related to target decision",
    "koi_fpflag_ec": "false-positive flag related to target decision",
}

columns_not_used = {
    column: reason
    for column, reason in columns_not_used.items()
    if column in modeling_df.columns
}

display(
    pd.DataFrame(
        [{"Column": column, "Reason": reason} for column, reason in columns_not_used.items()]
    )
)
# Out:
# Rows removed because target is missing: 0
#              Column                                          Reason
# 0   koi_disposition                                   target column
# 1             kepid                               identifier column
# 2  koi_pdisposition                       another disposition label
# 3         koi_score         disposition score related to the target
# 4     koi_fpflag_nt  false-positive flag related to target decision
# 5     koi_fpflag_ss  false-positive flag related to target decision
# 6     koi_fpflag_co  false-positive flag related to target decision
# 7     koi_fpflag_ec  false-positive flag related to target decision

# %%
numeric_columns = modeling_df.select_dtypes(include=[np.number]).columns.tolist()
feature_columns = [column for column in numeric_columns if column not in columns_not_used]

all_missing_features = [column for column in feature_columns if modeling_df[column].isna().all()]
constant_features = [
    column for column in feature_columns
    if column not in all_missing_features and modeling_df[column].nunique(dropna=True) <= 1
]

feature_columns = [
    column for column in feature_columns
    if column not in set(all_missing_features + constant_features)
]

removed_feature_summary = pd.DataFrame([
    {"Column": column, "Reason": "all values are missing"}
    for column in all_missing_features
] + [
    {"Column": column, "Reason": "constant value"}
    for column in constant_features
])

if not removed_feature_summary.empty:
    display(removed_feature_summary.sort_values("Column"))

X = modeling_df[feature_columns].copy()
y = modeling_df[target_column].astype(str).copy()

numeric_features = feature_columns
categorical_features = []

print(f"Number of modelling features: {len(feature_columns)}")
print("Categorical features selected:", categorical_features)
print("Numerical features selected:")
print(numeric_features)
# Out:
#               Column                  Reason
# 25           dec_err          constant value
# 28         koi_eccen          constant value
# 7     koi_eccen_err1  all values are missing
# 8     koi_eccen_err2  all values are missing
# 0       koi_gmag_err  all values are missing
# 2       koi_imag_err  all values are missing
# 17     koi_incl_err1  all values are missing
# 18     koi_incl_err2  all values are missing
# 14       koi_ingress  all values are missing
# 15  koi_ingress_err1  all values are missing
# 16  koi_ingress_err2  all values are missing
# 4     koi_kepmag_err  all values are missing
# 27    koi_ldm_coeff3          constant value
# 26    koi_ldm_coeff4          constant value
# 9          koi_longp  all values are missing
# 10    koi_longp_err1  all values are missing
# 11    koi_longp_err2  all values are missing
# 6    koi_model_chisq  all values are missing
# 5      koi_model_dof  all values are missing
# 1       koi_rmag_err  all values are missing
# ...

# %% [markdown]
# This notebook uses numeric modelling features only. Text labels, names, comments, links, and provenance columns are left out to keep preprocessing simple and explainable for Review 1.

# %% [markdown]
# ## 11. Train/Test Split

# %%
X_train, X_test, y_train, y_test = train_test_split(
    X,
    y,
    test_size=TEST_SIZE,
    random_state=RANDOM_STATE,
    stratify=y,
)

print(f"X_train: {X_train.shape}")
print(f"X_test: {X_test.shape}")
print(f"y_train: {y_train.shape}")
print(f"y_test: {y_test.shape}")

display(pd.DataFrame({
    "train_percent": y_train.value_counts(normalize=True).mul(100).round(2),
    "test_percent": y_test.value_counts(normalize=True).mul(100).round(2),
}))
# Out:
# X_train: (7651, 99)
# X_test: (1913, 99)
# y_train: (7651,)
# y_test: (1913,)
#                  train_percent  test_percent
# koi_disposition
# FALSE POSITIVE           50.59         50.60
# CONFIRMED                28.73         28.75
# CANDIDATE                20.68         20.65

# %% [markdown]
# ## 12. Preprocessing Pipeline

# %%
numeric_transformer = Pipeline(steps=[
    ("imputer", SimpleImputer(strategy="median")),
    ("scaler", StandardScaler()),
])

preprocessor = ColumnTransformer(
    transformers=[
        ("numeric", numeric_transformer, numeric_features),
    ],
    remainder="drop",
    verbose_feature_names_out=False,
)

print("Preprocessing will be fitted only inside model pipelines using X_train.")
# Out:
# Preprocessing will be fitted only inside model pipelines using X_train.

# %%
def calculate_roc_auc(y_true, probabilities, classes):
    classes = np.asarray(classes)

    if len(classes) == 2:
        return roc_auc_score(
            y_true,
            probabilities[:, 1],
            labels=classes,
        )

    y_true_binarized = label_binarize(y_true, classes=classes)
    return roc_auc_score(
        y_true_binarized,
        probabilities,
        multi_class="ovr",
        average="weighted",
    )


def show_confusion_matrix(y_true, predictions, classes, title, save_path=None):
    matrix = confusion_matrix(y_true, predictions, labels=classes)
    fig, ax = plt.subplots(figsize=(6.5, 5.5), dpi=200)
    ConfusionMatrixDisplay(matrix, display_labels=classes).plot(
        cmap="Blues",
        ax=ax,
        xticks_rotation=25,
        colorbar=True,
    )
    ax.set_title(title, fontsize=13, fontweight="bold")
    ax.set_xlabel("Predicted label")
    ax.set_ylabel("Actual label")
    plt.tight_layout()

    if save_path is not None:
        save_path = Path(save_path)
        save_path.parent.mkdir(parents=True, exist_ok=True)
        fig.savefig(save_path, dpi=300, bbox_inches="tight")
        print(f"Saved figure: {save_path}")

    plt.show()


def show_ovr_roc_curves(y_true, probabilities, classes, title, save_path=None):
    classes = np.asarray(classes)
    y_true_binarized = label_binarize(y_true, classes=classes)

    fig, ax = plt.subplots(figsize=(8, 6), dpi=200)
    for class_index, class_name in enumerate(classes):
        fpr, tpr, _ = roc_curve(
            y_true_binarized[:, class_index],
            probabilities[:, class_index],
        )
        class_auc = roc_auc_score(
            y_true_binarized[:, class_index],
            probabilities[:, class_index],
        )
        ax.plot(fpr, tpr, lw=1.8, label=f"{class_name} (AUC {class_auc:.3f})")

    ax.plot([0, 1], [0, 1], "k--", lw=1, label="Random baseline")
    ax.set_title(title, fontsize=13, fontweight="bold")
    ax.set_xlabel("False Positive Rate")
    ax.set_ylabel("True Positive Rate")
    ax.legend(loc="lower right")
    sns.despine(ax=ax)
    plt.tight_layout()

    if save_path is not None:
        save_path = Path(save_path)
        save_path.parent.mkdir(parents=True, exist_ok=True)
        fig.savefig(save_path, dpi=300, bbox_inches="tight")
        print(f"Saved figure: {save_path}")

    plt.show()

# %% [markdown]
# ## 11. Logistic Regression
#
# Logistic Regression is used as the baseline classification algorithm for this project. It estimates the probability of an observation belonging to each class and assigns the class with the highest probability.
#
# For this multiclass KOI classification problem, Logistic Regression uses a multinomial-style multiclass approach internally. The model is placed inside the preprocessing pipeline so that missing values are imputed and numerical features are standardized using parameters learned only from the training data.
#
# The coefficients can also be interpreted to understand how the modelling features influence the predicted class probabilities.

# %%
from sklearn.linear_model import LogisticRegression

logistic_pipeline = Pipeline(steps=[
    ("preprocess", preprocessor),
    ("model", LogisticRegression(
        max_iter=2000,
        random_state=RANDOM_STATE
    )),
])

logistic_pipeline.fit(X_train, y_train)

logistic_predictions = logistic_pipeline.predict(X_test)
logistic_probabilities = logistic_pipeline.predict_proba(X_test)
logistic_classes = logistic_pipeline.classes_

logistic_metrics = {
    "Model": "Logistic Regression",
    "Accuracy": accuracy_score(y_test, logistic_predictions),
    "Precision_Weighted": precision_score(
        y_test,
        logistic_predictions,
        average="weighted",
        zero_division=0
    ),
    "Recall_Weighted": recall_score(
        y_test,
        logistic_predictions,
        average="weighted",
        zero_division=0
    ),
    "F1_Weighted": f1_score(
        y_test,
        logistic_predictions,
        average="weighted",
        zero_division=0
    ),
    "ROC_AUC_OvR": calculate_roc_auc(
        y_test,
        logistic_probabilities,
        logistic_classes
    ),
}

print("Logistic Regression classification report")
print(
    classification_report(
        y_test,
        logistic_predictions,
        labels=logistic_classes,
        zero_division=0
    )
)

display(pd.DataFrame([logistic_metrics]).round(4))
# Out:
# Logistic Regression classification report
#                 precision    recall  f1-score   support
#
#      CANDIDATE       0.67      0.52      0.59       395
#      CONFIRMED       0.84      0.91      0.87       550
# FALSE POSITIVE       0.86      0.89      0.87       968
#
#       accuracy                           0.82      1913
#      macro avg       0.79      0.77      0.78      1913
#   weighted avg       0.81      0.82      0.81      1913
#                  Model  Accuracy  Precision_Weighted  Recall_Weighted  \
# 0  Logistic Regression    0.8197              0.8116           0.8197
#
#    F1_Weighted  ROC_AUC_OvR
# 0       0.8132       0.9368

# %% [markdown]
# ### Logistic Regression Visualisations

# %%
logistic_figure_dir = project_root / "notebooks" / "figures" / "Logistic Regression"

show_confusion_matrix(
    y_test,
    logistic_predictions,
    logistic_classes,
    "Logistic Regression - Confusion Matrix",
    logistic_figure_dir / "confusion_matrix.png"
)

show_ovr_roc_curves(
    y_test,
    logistic_probabilities,
    logistic_classes,
    "Logistic Regression - One-vs-Rest ROC Curves",
    logistic_figure_dir / "roc_curves.png"
)
# Out:
# Saved figure: /Users/nimaldanyathk/git/ML-Capstone_project/notebooks/figures/Logistic Regression/confusion_matrix.png
# Saved figure: /Users/nimaldanyathk/git/ML-Capstone_project/notebooks/figures/Logistic Regression/roc_curves.png

# %% [markdown]
# ## 12. K-Nearest Neighbors
#
# K-Nearest Neighbors (KNN) classifies an observation based on the classes of its nearest training observations. The number of neighbors, k, controls the balance between local and smoother decision boundaries.
#
# Feature scaling is important for KNN because the algorithm relies on distances between observations. Without scaling, features with larger numerical ranges could dominate the distance calculation.
#
# A baseline model is first trained, followed by hyperparameter tuning of k and the distance metric. Weighted F1-score is used as the tuning metric so that performance across the three KOI classes is considered while accounting for their different class frequencies.

# %%
from sklearn.neighbors import KNeighborsClassifier

knn_pipeline = Pipeline(steps=[
    ("preprocess", preprocessor),
    ("model", KNeighborsClassifier(
        n_neighbors=5,
        metric="minkowski"
    )),
])

knn_pipeline.fit(X_train, y_train)

knn_predictions = knn_pipeline.predict(X_test)
knn_probabilities = knn_pipeline.predict_proba(X_test)
knn_classes = knn_pipeline.classes_

knn_metrics = {
    "Model": "K-Nearest Neighbors - Baseline",
    "Accuracy": accuracy_score(y_test, knn_predictions),
    "Precision_Weighted": precision_score(
        y_test,
        knn_predictions,
        average="weighted",
        zero_division=0
    ),
    "Recall_Weighted": recall_score(
        y_test,
        knn_predictions,
        average="weighted",
        zero_division=0
    ),
    "F1_Weighted": f1_score(
        y_test,
        knn_predictions,
        average="weighted",
        zero_division=0
    ),
    "ROC_AUC_OvR": calculate_roc_auc(
        y_test,
        knn_probabilities,
        knn_classes
    ),
}

print("K-Nearest Neighbors baseline classification report")
print(
    classification_report(
        y_test,
        knn_predictions,
        labels=knn_classes,
        zero_division=0
    )
)

display(pd.DataFrame([knn_metrics]).round(4))
# Out:
# K-Nearest Neighbors baseline classification report
#                 precision    recall  f1-score   support
#
#      CANDIDATE       0.57      0.51      0.54       395
#      CONFIRMED       0.75      0.91      0.83       550
# FALSE POSITIVE       0.87      0.80      0.83       968
#
#       accuracy                           0.77      1913
#      macro avg       0.73      0.74      0.73      1913
#   weighted avg       0.77      0.77      0.77      1913
#                             Model  Accuracy  Precision_Weighted  \
# 0  K-Nearest Neighbors - Baseline    0.7737              0.7736
#
#    Recall_Weighted  F1_Weighted  ROC_AUC_OvR
# 0           0.7737       0.7705       0.9006

# %% [markdown]
# ### KNN Hyperparameter Tuning
#
# The KNN model is tuned using GridSearchCV. The main parameters considered are the number of neighbors (`k`) and the distance metric.
#
# Smaller values of k allow the model to respond more closely to local patterns, while larger values produce a smoother decision boundary. The distance metric determines how similarity between observations is measured.

# %%
knn_tuning_pipeline = Pipeline(steps=[
    ("preprocess", preprocessor),
    ("model", KNeighborsClassifier()),
])

knn_param_grid = {
    "model__n_neighbors": [3, 5, 7, 9, 11, 15],
    "model__metric": ["euclidean", "manhattan", "minkowski"],
}

knn_grid_search = GridSearchCV(
    knn_tuning_pipeline,
    param_grid=knn_param_grid,
    scoring="f1_weighted",
    cv=5,
    n_jobs=-1,
)

knn_grid_search.fit(X_train, y_train)

tuned_knn_pipeline = knn_grid_search.best_estimator_

tuned_knn_predictions = tuned_knn_pipeline.predict(X_test)
tuned_knn_probabilities = tuned_knn_pipeline.predict_proba(X_test)
tuned_knn_classes = tuned_knn_pipeline.classes_

tuned_knn_metrics = {
    "Model": "K-Nearest Neighbors - Tuned",
    "Accuracy": accuracy_score(y_test, tuned_knn_predictions),
    "Precision_Weighted": precision_score(
        y_test,
        tuned_knn_predictions,
        average="weighted",
        zero_division=0
    ),
    "Recall_Weighted": recall_score(
        y_test,
        tuned_knn_predictions,
        average="weighted",
        zero_division=0
    ),
    "F1_Weighted": f1_score(
        y_test,
        tuned_knn_predictions,
        average="weighted",
        zero_division=0
    ),
    "ROC_AUC_OvR": calculate_roc_auc(
        y_test,
        tuned_knn_probabilities,
        tuned_knn_classes
    ),
}

knn_f1_improvement = (
    tuned_knn_metrics["F1_Weighted"]
    - knn_metrics["F1_Weighted"]
)

print("Best KNN parameters:")
print(knn_grid_search.best_params_)

print(
    f"Best CV weighted F1: "
    f"{knn_grid_search.best_score_:.4f}"
)

print(
    f"Baseline test weighted F1: "
    f"{knn_metrics['F1_Weighted']:.4f}"
)

print(
    f"Tuned test weighted F1: "
    f"{tuned_knn_metrics['F1_Weighted']:.4f}"
)

print(
    f"Improvement from baseline: "
    f"{knn_f1_improvement:.4f}"
)

print("\nTuned KNN classification report")
print(
    classification_report(
        y_test,
        tuned_knn_predictions,
        labels=tuned_knn_classes,
        zero_division=0
    )
)

display(pd.DataFrame([
    {
        "Item": "Best parameters",
        "Value": knn_grid_search.best_params_
    },
    {
        "Item": "Best CV weighted F1",
        "Value": round(knn_grid_search.best_score_, 4)
    },
    {
        "Item": "Baseline test weighted F1",
        "Value": round(knn_metrics["F1_Weighted"], 4)
    },
    {
        "Item": "Tuned test weighted F1",
        "Value": round(tuned_knn_metrics["F1_Weighted"], 4)
    },
    {
        "Item": "Improvement from baseline",
        "Value": round(knn_f1_improvement, 4)
    },
]))
# Out:
# Best KNN parameters:
# {'model__metric': 'manhattan', 'model__n_neighbors': 5}
# Best CV weighted F1: 0.7676
# Baseline test weighted F1: 0.7705
# Tuned test weighted F1: 0.7822
# Improvement from baseline: 0.0117
#
# Tuned KNN classification report
#                 precision    recall  f1-score   support
#
#      CANDIDATE       0.59      0.53      0.56       395
#      CONFIRMED       0.77      0.91      0.83       550
# FALSE POSITIVE       0.87      0.81      0.84       968
#
#       accuracy                           0.78      1913
#      macro avg       0.74      0.75      0.75      1913
#   weighted avg       0.78      0.78      0.78      1913
#                         Item  \
# 0            Best parameters
# 1        Best CV weighted F1
# 2  Baseline test weighted F1
# 3     Tuned test weighted F1
# 4  Improvement from baseline
#
#                                                Value
# 0  {'model__metric': 'manhattan', 'model__n_neigh...
# ...

# %% [markdown]
# ### K-Nearest Neighbors Visualisations

# %% [markdown]
# Preprocessing follows the PDF rule: imputing and scaling are fitted on the training set only through the sklearn pipeline, then applied to the test set through the same fitted pipeline.

# %%
knn_figure_dir = project_root / "notebooks" / "figures" / "K-Nearest Neighbors"

show_confusion_matrix(
    y_test,
    tuned_knn_predictions,
    tuned_knn_classes,
    "K-Nearest Neighbors - Confusion Matrix",
    knn_figure_dir / "confusion_matrix.png"
)

show_ovr_roc_curves(
    y_test,
    tuned_knn_probabilities,
    tuned_knn_classes,
    "K-Nearest Neighbors - One-vs-Rest ROC Curves",
    knn_figure_dir / "roc_curves.png"
)
# Out:
# Saved figure: /Users/nimaldanyathk/git/ML-Capstone_project/notebooks/figures/K-Nearest Neighbors/confusion_matrix.png
# Saved figure: /Users/nimaldanyathk/git/ML-Capstone_project/notebooks/figures/K-Nearest Neighbors/roc_curves.png

# %% [markdown]
# ## 13. Gaussian Naive Bayes

# %% [markdown]
# Gaussian Naive Bayes uses Bayes' theorem to estimate the most likely class from the feature values. The "naive" part is the conditional independence assumption: after the class is known, each feature is treated as independent of the other features. For continuous numerical features, GaussianNB models each feature's likelihood within each class using a normal/Gaussian distribution. This makes it suitable for a numeric tabular baseline such as the KOI measurements, while staying easy to explain in viva. A key limitation is that real KOI features can be correlated, so the independence assumption may be violated and performance may suffer.

# %%
gnb_pipeline = Pipeline(steps=[
    ("preprocess", preprocessor),
    ("model", GaussianNB()),
])

gnb_pipeline.fit(X_train, y_train)

gnb_predictions = gnb_pipeline.predict(X_test)
gnb_probabilities = gnb_pipeline.predict_proba(X_test)
gnb_classes = gnb_pipeline.classes_

gnb_metrics = {
    "Model": "Gaussian Naive Bayes",
    "Accuracy": accuracy_score(y_test, gnb_predictions),
    "Precision_Weighted": precision_score(y_test, gnb_predictions, average="weighted", zero_division=0),
    "Recall_Weighted": recall_score(y_test, gnb_predictions, average="weighted", zero_division=0),
    "F1_Weighted": f1_score(y_test, gnb_predictions, average="weighted", zero_division=0),
    "ROC_AUC_OvR": calculate_roc_auc(y_test, gnb_probabilities, gnb_classes),
}

print("Gaussian Naive Bayes classification report")
print(classification_report(y_test, gnb_predictions, labels=gnb_classes, zero_division=0))

display(pd.DataFrame([gnb_metrics]).round(4))
# Out:
# Gaussian Naive Bayes classification report
#                 precision    recall  f1-score   support
#
#      CANDIDATE       0.29      0.40      0.34       395
#      CONFIRMED       0.61      0.97      0.75       550
# FALSE POSITIVE       0.96      0.50      0.66       968
#
#       accuracy                           0.61      1913
#      macro avg       0.62      0.62      0.58      1913
#   weighted avg       0.72      0.61      0.62      1913
#                   Model  Accuracy  Precision_Weighted  Recall_Weighted  \
# 0  Gaussian Naive Bayes    0.6142              0.7241           0.6142
#
#    F1_Weighted  ROC_AUC_OvR
# 0       0.6186       0.8769

# %% [markdown]
# ### Gaussian Naive Bayes Visualisations

# %%
gnb_figures_dir = project_root / "notebooks" / "figures" / "Gaussian Naive Bayes"

show_confusion_matrix(
    y_test,
    gnb_predictions,
    gnb_pipeline.classes_,
    "Gaussian Naive Bayes Confusion Matrix",
    save_path=gnb_figures_dir / "confusion_matrix.png",
)

show_ovr_roc_curves(
    y_test,
    gnb_probabilities,
    gnb_pipeline.classes_,
    "Gaussian Naive Bayes OvR ROC Curves",
    save_path=gnb_figures_dir / "roc_curves.png",
)
# Out:
# Saved figure: /Users/nimaldanyathk/git/ML-Capstone_project/notebooks/figures/Gaussian Naive Bayes/confusion_matrix.png
# Saved figure: /Users/nimaldanyathk/git/ML-Capstone_project/notebooks/figures/Gaussian Naive Bayes/roc_curves.png

# %% [markdown]
# ## 14. Decision Tree Classifier

# %%
tree_baseline_pipeline = Pipeline(steps=[
    ("preprocess", preprocessor),
    ("model", DecisionTreeClassifier(random_state=RANDOM_STATE)),
])

tree_baseline_pipeline.fit(X_train, y_train)

tree_baseline_predictions = tree_baseline_pipeline.predict(X_test)
tree_baseline_probabilities = tree_baseline_pipeline.predict_proba(X_test)
tree_baseline_classes = tree_baseline_pipeline.classes_

tree_baseline_metrics = {
    "Model": "Decision Tree Classifier - Baseline",
    "Accuracy": accuracy_score(y_test, tree_baseline_predictions),
    "Precision_Weighted": precision_score(y_test, tree_baseline_predictions, average="weighted", zero_division=0),
    "Recall_Weighted": recall_score(y_test, tree_baseline_predictions, average="weighted", zero_division=0),
    "F1_Weighted": f1_score(y_test, tree_baseline_predictions, average="weighted", zero_division=0),
    "ROC_AUC_OvR": calculate_roc_auc(y_test, tree_baseline_probabilities, tree_baseline_classes),
}

print("Decision Tree baseline classification report")
print(classification_report(y_test, tree_baseline_predictions, labels=tree_baseline_classes, zero_division=0))

display(pd.DataFrame([tree_baseline_metrics]).round(4))
# Out:
# Decision Tree baseline classification report
#                 precision    recall  f1-score   support
#
#      CANDIDATE       0.55      0.57      0.56       395
#      CONFIRMED       0.86      0.82      0.84       550
# FALSE POSITIVE       0.85      0.87      0.86       968
#
#       accuracy                           0.79      1913
#      macro avg       0.76      0.75      0.75      1913
#   weighted avg       0.80      0.79      0.79      1913
#                                  Model  Accuracy  Precision_Weighted  \
# 0  Decision Tree Classifier - Baseline     0.793               0.795
#
#    Recall_Weighted  F1_Weighted  ROC_AUC_OvR
# 0            0.793       0.7938       0.8383

# %% [markdown]
# ### Decision Tree Baseline Visualisation

# %%
tree_figures_dir = project_root / "notebooks" / "figures" / "Decision Tree Classifier"

show_confusion_matrix(
    y_test,
    tree_baseline_predictions,
    tree_baseline_pipeline.classes_,
    "Decision Tree Baseline Confusion Matrix",
    save_path=tree_figures_dir / "baseline_confusion_matrix.png",
)
# Out:
# Saved figure: /Users/nimaldanyathk/git/ML-Capstone_project/notebooks/figures/Decision Tree Classifier/baseline_confusion_matrix.png

# %% [markdown]
# ## 15. Decision Tree Hyperparameter Tuning

# %%
tree_tuning_pipeline = Pipeline(steps=[
    ("preprocess", preprocessor),
    ("model", DecisionTreeClassifier(random_state=RANDOM_STATE)),
])

param_grid = {
    "model__criterion": ["gini", "entropy"],
    "model__max_depth": [None, 3, 5, 8, 10],
    "model__min_samples_split": [2, 5, 10],
    "model__min_samples_leaf": [1, 2, 4],
}

tree_grid_search = GridSearchCV(
    tree_tuning_pipeline,
    param_grid=param_grid,
    scoring="f1_weighted",
    cv=5,
    n_jobs=-1,
)

tree_grid_search.fit(X_train, y_train)
tuned_tree_pipeline = tree_grid_search.best_estimator_

tuned_tree_predictions = tuned_tree_pipeline.predict(X_test)
tuned_tree_probabilities = tuned_tree_pipeline.predict_proba(X_test)
tuned_tree_classes = tuned_tree_pipeline.classes_

tuned_tree_metrics = {
    "Model": "Decision Tree Classifier - Tuned",
    "Accuracy": accuracy_score(y_test, tuned_tree_predictions),
    "Precision_Weighted": precision_score(y_test, tuned_tree_predictions, average="weighted", zero_division=0),
    "Recall_Weighted": recall_score(y_test, tuned_tree_predictions, average="weighted", zero_division=0),
    "F1_Weighted": f1_score(y_test, tuned_tree_predictions, average="weighted", zero_division=0),
    "ROC_AUC_OvR": calculate_roc_auc(y_test, tuned_tree_probabilities, tuned_tree_classes),
}

tree_f1_improvement = tuned_tree_metrics["F1_Weighted"] - tree_baseline_metrics["F1_Weighted"]

print("Best Decision Tree parameters:")
print(tree_grid_search.best_params_)
print(f"Best CV weighted F1: {tree_grid_search.best_score_:.4f}")
print(f"Baseline test weighted F1: {tree_baseline_metrics['F1_Weighted']:.4f}")
print(f"Tuned test weighted F1: {tuned_tree_metrics['F1_Weighted']:.4f}")
print(f"Improvement from baseline: {tree_f1_improvement:.4f}")
print("\nTuned Decision Tree classification report")
print(classification_report(y_test, tuned_tree_predictions, labels=tuned_tree_classes, zero_division=0))

display(pd.DataFrame([
    {"Item": "Best parameters", "Value": tree_grid_search.best_params_},
    {"Item": "Best CV weighted F1", "Value": round(tree_grid_search.best_score_, 4)},
    {"Item": "Baseline test weighted F1", "Value": round(tree_baseline_metrics["F1_Weighted"], 4)},
    {"Item": "Tuned test weighted F1", "Value": round(tuned_tree_metrics["F1_Weighted"], 4)},
    {"Item": "Improvement from baseline", "Value": round(tree_f1_improvement, 4)},
]))
# Out:
# Best Decision Tree parameters:
# {'model__criterion': 'gini', 'model__max_depth': 8, 'model__min_samples_leaf': 1, 'model__min_samples_split': 2}
# Best CV weighted F1: 0.8008
# Baseline test weighted F1: 0.7938
# Tuned test weighted F1: 0.8190
# Improvement from baseline: 0.0252
#
# Tuned Decision Tree classification report
#                 precision    recall  f1-score   support
#
#      CANDIDATE       0.63      0.59      0.61       395
#      CONFIRMED       0.85      0.91      0.88       550
# FALSE POSITIVE       0.87      0.86      0.87       968
#
#       accuracy                           0.82      1913
#      macro avg       0.79      0.79      0.79      1913
#   weighted avg       0.82      0.82      0.82      1913
#                         Item  \
# 0            Best parameters
# 1        Best CV weighted F1
# 2  Baseline test weighted F1
# 3     Tuned test weighted F1
# 4  Improvement from baseline
#
#                                                Value
# ...

# %% [markdown]
# ### Tuned Decision Tree Visualisations

# %%
show_confusion_matrix(
    y_test,
    tuned_tree_predictions,
    tuned_tree_pipeline.classes_,
    "Decision Tree Tuned Confusion Matrix",
    save_path=tree_figures_dir / "confusion_matrix.png",
)

show_ovr_roc_curves(
    y_test,
    tuned_tree_probabilities,
    tuned_tree_pipeline.classes_,
    "Tuned Decision Tree OvR ROC Curves",
    save_path=tree_figures_dir / "roc_curves.png",
)

fitted_preprocessor = tuned_tree_pipeline.named_steps["preprocess"]
fitted_tree = tuned_tree_pipeline.named_steps["model"]
feature_names = fitted_preprocessor.get_feature_names_out()

print("The displayed tree is truncated to the first few levels for readability; the fitted model itself is unchanged.")

fig, ax = plt.subplots(figsize=(24, 10), dpi=200)
plot_tree(
    fitted_tree,
    feature_names=feature_names,
    class_names=fitted_tree.classes_,
    max_depth=3,
    filled=True,
    rounded=True,
    impurity=False,
    fontsize=8,
    ax=ax,
)
ax.set_title("Tuned Decision Tree - Top Levels")
plt.tight_layout()

tree_plot_path = tree_figures_dir / "tree_top_levels.png"
tree_plot_path.parent.mkdir(parents=True, exist_ok=True)
fig.savefig(tree_plot_path, dpi=300, bbox_inches="tight")
print(f"Saved figure: {tree_plot_path}")
plt.show()

feature_importance = (
    pd.DataFrame({
        "Feature": feature_names,
        "Importance": fitted_tree.feature_importances_,
    })
    .sort_values("Importance", ascending=False)
    .reset_index(drop=True)
)

display(feature_importance.head(15))

fig, ax = plt.subplots(figsize=(10, 7), dpi=200)
sns.barplot(data=feature_importance.head(15), y="Feature", x="Importance", ax=ax)
ax.set_title("Top Decision Tree Feature Importances", fontsize=13, fontweight="bold")
ax.set_xlabel("Importance")
ax.set_ylabel("Feature")
plt.tight_layout()

importance_plot_path = tree_figures_dir / "feature_importances.png"
importance_plot_path.parent.mkdir(parents=True, exist_ok=True)
fig.savefig(importance_plot_path, dpi=300, bbox_inches="tight")
print(f"Saved figure: {importance_plot_path}")
plt.show()
# Out:
# Saved figure: /Users/nimaldanyathk/git/ML-Capstone_project/notebooks/figures/Decision Tree Classifier/confusion_matrix.png
# Saved figure: /Users/nimaldanyathk/git/ML-Capstone_project/notebooks/figures/Decision Tree Classifier/roc_curves.png
# The displayed tree is truncated to the first few levels for readability; the fitted model itself is unchanged.
# Saved figure: /Users/nimaldanyathk/git/ML-Capstone_project/notebooks/figures/Decision Tree Classifier/tree_top_levels.png
#               Feature  Importance
# 0       koi_smet_err2    0.229269
# 1    koi_fwm_stat_sig    0.131399
# 2     koi_max_mult_ev    0.112598
# 3      koi_dikco_msky    0.081305
# 4            koi_prad    0.067024
# 5             koi_ror    0.052403
# 6             koi_dor    0.047838
# 7   koi_duration_err1    0.046350
# 8          koi_period    0.031081
# 9   koi_dicco_mra_err    0.016377
# 10   koi_num_transits    0.014305
# 11      koi_srho_err2    0.013404
# 12     koi_dicco_msky    0.013207
# ...

# %% [markdown]
# **Observation:** The tuned tree relies most heavily on `koi_smet_err2` (importance 0.229), followed by `koi_fwm_stat_sig` (0.131), `koi_max_mult_ev` (0.113), and `koi_dikco_msky` (0.081). Planetary radius (`koi_prad`, 0.067), radius ratio (`koi_ror`, 0.052), and orbital distance ratio (`koi_dor`, 0.048) also contribute. Importance is distributed across stellar uncertainty, centroid, transit-event, and planetary measurements, which supports the earlier conclusion that classification depends on several interacting signals rather than one dominant EDA feature. These impurity-based scores describe the fitted tree and should not be interpreted as causal effects.

# %% [markdown]
# ## 16. Model Comparison

# %%
comparison_table = pd.DataFrame([
    gnb_metrics,
    tree_baseline_metrics,
    tuned_tree_metrics,
]).round(4)

comparison_table = comparison_table.sort_values("F1_Weighted", ascending=False).reset_index(drop=True)
display(comparison_table)
# Out:
#                                  Model  Accuracy  Precision_Weighted  \
# 0     Decision Tree Classifier - Tuned    0.8207              0.8180
# 1  Decision Tree Classifier - Baseline    0.7930              0.7950
# 2                 Gaussian Naive Bayes    0.6142              0.7241
#
#    Recall_Weighted  F1_Weighted  ROC_AUC_OvR
# 0           0.8207       0.8190       0.9233
# 1           0.7930       0.7938       0.8383
# 2           0.6142       0.6186       0.8769

# %% [markdown]
# **Observation:** The tuned decision tree is the strongest evaluated model, with 0.8207 accuracy, 0.8190 weighted F1, and 0.9233 one-vs-rest ROC AUC. Tuning improves weighted F1 by 0.0252 over the baseline tree and reduces its overall classification errors. The tuned confusion matrix and class report show strong performance for `CONFIRMED` (F1 0.88) and `FALSE POSITIVE` (F1 0.87), while `CANDIDATE` remains the hardest class (F1 0.61) because it is more often confused with the other dispositions. Gaussian Naive Bayes trails on accuracy and weighted F1 (0.6142 and 0.6186), although its ROC AUC of 0.8769 indicates better probability ranking than its hard-label results alone suggest.

# %% [markdown]
# ## 17. Support Vector Classifier (SVC)

# %%
#svc import
from sklearn.svm import SVC

#same pipeline shape as the other classifiers; probability=True enables ROC-AUC
svc_pipeline = Pipeline(steps=[
    ("preprocess", preprocessor),
    ("model", SVC(probability=True, random_state=RANDOM_STATE)),
])

#tune C, gamma and kernel on weighted F1 (same scoring and cv as the tree)
svc_param_grid = [
    {"model__kernel": ["rbf"], "model__C": [1, 10, 100], "model__gamma": ["scale", 0.01]},
    {"model__kernel": ["linear"], "model__C": [1, 10]},
]

svc_grid_search = GridSearchCV(
    svc_pipeline, param_grid=svc_param_grid,
    scoring="f1_weighted", cv=5, n_jobs=-1,
)
svc_grid_search.fit(X_train, y_train)
svc_pipeline_best = svc_grid_search.best_estimator_

svc_predictions = svc_pipeline_best.predict(X_test)
svc_probabilities = svc_pipeline_best.predict_proba(X_test)
svc_classes = svc_pipeline_best.classes_

svc_metrics = {
    "Model": "Support Vector Classifier",
    "Accuracy": accuracy_score(y_test, svc_predictions),
    "Precision_Weighted": precision_score(y_test, svc_predictions, average="weighted", zero_division=0),
    "Recall_Weighted": recall_score(y_test, svc_predictions, average="weighted", zero_division=0),
    "F1_Weighted": f1_score(y_test, svc_predictions, average="weighted", zero_division=0),
    "ROC_AUC_OvR": calculate_roc_auc(y_test, svc_probabilities, svc_classes),
}

print("Best SVC parameters:", svc_grid_search.best_params_)
print("Best CV weighted F1:", round(svc_grid_search.best_score_, 4))
print("\nSupport Vector Classifier classification report")
print(classification_report(y_test, svc_predictions, labels=svc_classes, zero_division=0))

display(pd.DataFrame([svc_metrics]).round(4))
# Out:
# Best SVC parameters: {'model__C': 10, 'model__gamma': 'scale', 'model__kernel': 'rbf'}
# Best CV weighted F1: 0.8193
#
# Support Vector Classifier classification report
#                 precision    recall  f1-score   support
#
#      CANDIDATE       0.62      0.57      0.60       395
#      CONFIRMED       0.86      0.90      0.88       550
# FALSE POSITIVE       0.87      0.88      0.88       968
#
#       accuracy                           0.82      1913
#      macro avg       0.79      0.78      0.78      1913
#   weighted avg       0.82      0.82      0.82      1913
#                        Model  Accuracy  Precision_Weighted  Recall_Weighted  \
# 0  Support Vector Classifier    0.8223              0.8179           0.8223
#
#    F1_Weighted  ROC_AUC_OvR
# 0       0.8197       0.9442

# %% [markdown]
# ### Chosen hyperparameters
#
# The grid picked `kernel='rbf'`, `C=10`, `gamma='scale'` (best CV weighted F1 about 0.82). A moderate `C` with
# the default `scale` gamma is a mild RBF fit; the grid preferred it over a harder `C=100`, a more local
# `gamma=0.01`, and the linear kernel, so a gentle non-linear boundary generalises best on these transit
# features.

# %%
#confusion matrix for svc, saved under figures/SVC/
import os
os.makedirs("figures/SVC", exist_ok=True)

fig, ax = plt.subplots(figsize=(6.5, 5.5), dpi=200)
ConfusionMatrixDisplay(
    confusion_matrix(y_test, svc_predictions, labels=svc_classes),
    display_labels=svc_classes,
).plot(cmap="Blues", ax=ax, xticks_rotation=25, colorbar=True)
ax.set_title("SVC Confusion Matrix", fontsize=13, fontweight="bold")
plt.tight_layout()
plt.savefig("figures/SVC/confusion_matrix.png", dpi=300, bbox_inches="tight")
plt.show()

# %%
#one-vs-rest roc curves for svc, saved under figures/SVC/
svc_y_test_bin = label_binarize(y_test, classes=svc_classes)

fig, ax = plt.subplots(figsize=(8, 6), dpi=200)
for idx, class_name in enumerate(svc_classes):
    fpr, tpr, _ = roc_curve(svc_y_test_bin[:, idx], svc_probabilities[:, idx])
    auc = roc_auc_score(svc_y_test_bin[:, idx], svc_probabilities[:, idx])
    ax.plot(fpr, tpr, lw=1.8, label=f"{class_name} (AUC {auc:.3f})")

ax.plot([0, 1], [0, 1], "k--", lw=1, label="random baseline")
ax.set_title("SVC One-vs-Rest ROC Curves", fontsize=13, fontweight="bold")
ax.set_xlabel("False Positive Rate")
ax.set_ylabel("True Positive Rate")
ax.legend(loc="lower right")
sns.despine(ax=ax)
plt.tight_layout()
plt.savefig("figures/SVC/roc_curves.png", dpi=300, bbox_inches="tight")
plt.show()

# %%
#full classification comparison including svc (same format as section 17)
svc_comparison_table = pd.DataFrame([
    gnb_metrics,
    tree_baseline_metrics,
    tuned_tree_metrics,
    svc_metrics,
]).round(4)

svc_comparison_table = svc_comparison_table.sort_values("F1_Weighted", ascending=False).reset_index(drop=True)
display(svc_comparison_table)
# Out:
#                                  Model  Accuracy  Precision_Weighted  \
# 0            Support Vector Classifier    0.8223              0.8179
# 1     Decision Tree Classifier - Tuned    0.8207              0.8180
# 2  Decision Tree Classifier - Baseline    0.7930              0.7950
# 3                 Gaussian Naive Bayes    0.6142              0.7241
#
#    Recall_Weighted  F1_Weighted  ROC_AUC_OvR
# 0           0.8223       0.8197       0.9442
# 1           0.8207       0.8190       0.9233
# 2           0.7930       0.7938       0.8383
# 3           0.6142       0.6186       0.8769

# %% [markdown]
# ### Results
#
# The tuned SVC reaches **accuracy 0.82, weighted F1 0.82, and one-vs-rest ROC-AUC 0.94** on the held-out test
# set. That is essentially tied with the tuned Decision Tree for the best weighted F1 (both about 0.82) and
# comfortably ahead of Gaussian Naive Bayes (weighted F1 about 0.62, held back by its independence and
# normality assumptions on correlated transit features).
#
# Per class it is strong on `CONFIRMED` and `FALSE POSITIVE` (F1 about 0.88 each) but weaker on `CANDIDATE`
# (F1 about 0.60). The confusion matrix shows candidates being split across the other two classes, which is
# expected: a candidate is by definition an object not yet resolved either way, so it shares features with
# both. The high ROC-AUC (0.94) shows the predicted probabilities still rank objects well even where the hard
# label is uncertain.

# %% [markdown]
# ## 18. Consolidated Part-A Model Comparison
#
# All five Review-1 classifiers side by side on the same stratified test split (KNN and Decision Tree are shown
# as both baseline and tuned). Models are ranked by weighted F1, and the bar chart gives a one-glance summary of
# weighted F1 and one-vs-rest ROC-AUC.

# %%
#consolidated part-a comparison: all five review-1 classifiers on the same split
part_a_table = pd.DataFrame([
    logistic_metrics,
    knn_metrics,
    tuned_knn_metrics,
    gnb_metrics,
    tree_baseline_metrics,
    tuned_tree_metrics,
    svc_metrics,
]).round(4)
part_a_table = part_a_table.sort_values("F1_Weighted", ascending=False).reset_index(drop=True)
display(part_a_table)
# Out:
#                                  Model  Accuracy  Precision_Weighted  \
# 0            Support Vector Classifier    0.8223              0.8179
# 1     Decision Tree Classifier - Tuned    0.8207              0.8180
# 2                  Logistic Regression    0.8197              0.8116
# 3  Decision Tree Classifier - Baseline    0.7930              0.7950
# 4          K-Nearest Neighbors - Tuned    0.7846              0.7849
# 5       K-Nearest Neighbors - Baseline    0.7737              0.7736
# 6                 Gaussian Naive Bayes    0.6142              0.7241
#
#    Recall_Weighted  F1_Weighted  ROC_AUC_OvR
# 0           0.8223       0.8197       0.9442
# 1           0.8207       0.8190       0.9233
# 2           0.8197       0.8132       0.9368
# 3           0.7930       0.7938       0.8383
# 4           0.7846       0.7822       0.9133
# 5           0.7737       0.7705       0.9006
# 6           0.6142       0.6186       0.8769

# %%
#visual comparison of the part-a classifiers
import os
f1_sorted = part_a_table.sort_values("F1_Weighted", ascending=True)
auc_sorted = part_a_table.sort_values("ROC_AUC_OvR", ascending=True)
best_f1 = f1_sorted["Model"].iloc[-1]
best_auc = auc_sorted["Model"].iloc[-1]

fig, axes = plt.subplots(1, 2, figsize=(14, 6), dpi=200)

axes[0].barh(f1_sorted["Model"], f1_sorted["F1_Weighted"],
             color=["#12a67a" if m == best_f1 else "#2f6df6" for m in f1_sorted["Model"]])
axes[0].set_xlabel("Weighted F1 (higher is better)")
axes[0].set_title("Weighted F1 by model", fontsize=13, fontweight="bold")
axes[0].set_xlim(0, 1)
for y, v in enumerate(f1_sorted["F1_Weighted"]):
    axes[0].text(v, y, f" {v:.3f}", va="center", fontsize=9)

axes[1].barh(auc_sorted["Model"], auc_sorted["ROC_AUC_OvR"],
             color=["#12a67a" if m == best_auc else "#e07b39" for m in auc_sorted["Model"]])
axes[1].set_xlabel("ROC-AUC OvR (higher is better)")
axes[1].set_title("ROC-AUC by model", fontsize=13, fontweight="bold")
axes[1].set_xlim(0, 1)
for y, v in enumerate(auc_sorted["ROC_AUC_OvR"]):
    axes[1].text(v, y, f" {v:.3f}", va="center", fontsize=9)

for ax in axes:
    sns.despine(ax=ax)
plt.tight_layout()
os.makedirs("figures/Comparison", exist_ok=True)
plt.savefig("figures/Comparison/classification_model_comparison.png", dpi=300, bbox_inches="tight")
plt.show()

# %% [markdown]
# **Observation:** The Support Vector Classifier leads on both weighted F1 (0.820) and ROC-AUC (0.944), with the
# tuned Decision Tree (F1 0.819) and Logistic Regression (F1 0.813, and the second-best ROC-AUC at 0.937) close
# behind. Tuning clearly helped: KNN improved from 0.771 to 0.782 and the Decision Tree from 0.794 to 0.819 in
# weighted F1. Gaussian Naive Bayes trails at F1 0.619 because its feature-independence assumption is badly
# violated by the strongly correlated transit measurements; its much higher ROC-AUC (0.877) shows it still ranks
# objects reasonably but assigns hard labels poorly, mostly on the ambiguous CANDIDATE class.
